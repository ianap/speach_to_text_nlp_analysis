# %% [markdown]
# ---
# ## Key phrase sentiment analysis pipeline
#
# This Jupyter notebook contains a pipeline for extracting targeted sentiment for key phrases in interview responses using AWS Comprehend. The pipeline first identifies the key phrases in the responses using the AWS Comprehend Key Phrases Detect API, and then extracts the context surrounding each key phrase to provide additional context for sentiment analysis. The pipeline can be used to identify patterns in how interviewees express positive or negative sentiment towards specific key phrase.
#
# ### Pipeline steps
# The pipeline consists of the following steps:
#
# 1. __Loading the data__: The interview transcript, speaker classification results, and reference question list are loaded into the notebook.
#
# 2. __Preprocessing__: The transcript is preprocessed to remove any unnecessary elements, such as timestamps or speaker tags.
#
# 3. __Identifying key phrases__: The pipeline calls the AWS Comprehend Key Phrases Detect API for each response in the transcript, and selects only the top key phrases with a score above 0.99. These key phrases are then used as the basis for sentiment analysis.
#
# 4. __Extracting context__: For each top key phrase, the pipeline extracts the context surrounding the phrase by taking 10 words before and after the phrase in the response. This provides additional context for sentiment analysis and helps to ensure that the sentiment is targeted specifically to the key phrase.
#
# 5. __Detecting sentiment__: The pipeline calls the AWS Comprehend Detect Sentiment API for each extracted context, and records the sentiment score and sentiment label (positive, negative, neutral, or mixed) for each key phrase.
#
# 6. __Aggregating results__: The pipeline can be used to aggregate the sentiment analysis results across multiple interviewees and/or questions, providing a more comprehensive understanding of the sentiment towards specific topics or themes.
#
# ### Conclusion
# This pipeline provides a powerful tool for analyzing the sentiment expressed in interview responses. By identifying key phrases and extracting the context surrounding them, the pipeline enables targeted sentiment analysis that can reveal patterns and insights that might otherwise be missed.
#
# ---

# %%
import time
import boto3
from botocore.exceptions import ClientError
import requests
import pandas as pd
import os

# %%
comprehend = boto3.client('comprehend', region_name='us-east-1')

# %% [markdown]
# ### Step 1: Loading the data

# %%
BUCKET='cnatest' # Or whatever you called your bucket
data_key = 'transcript_with_mapped_questions_and_answers.csv' # Where the file is within your bucket
data_location = 's3://{}/{}'.format(BUCKET, data_key)
df = pd.read_csv(data_location)

# %%
df.head(10)
# Out:
#                                 responce_to_question  \
# 0  As a national savings for the healthcare syste...
# 1  Fees will be paid to GPS based on the health r...
# 2       From your point of view What is Healthier SG
# 3  If there's one thing that you could you know c...
# 4  Should the typical patient be concerned about ...
# 5  The idea of having family doctors is something...
# 6  Will this also add on to increasing burdens fo...
# 7  when you look at our health care system what w...
#
#                                                 text
# 0  if this is running correctly? And we get buy i...
# 1  start first. What I used to hear a lot of is t...
# 2  I think healthier S. G. Is a whole rethinking ...
# 3  for me I think information to unify all the in...
# 4  over time. We will see a general increase in c...
# 5  I don't think we're only doing it now. I think...
# 6  be honest and say that it is going to be certa...
# 7  [PII] I would actually just extend a little bi...

# %%
list_questions = df.responce_to_question.tolist()

# %% [markdown]
# ### Step 2: Preprocessing

# %%
def clean_text(df):
    """Preprocessing review text.
    The text becomes Comprehend compatible as a result.
    This is the most important preprocessing step.
    """
    # Encode and decode reviews
    df['text'] = df['text'].str.encode("utf-8", "ignore")
    df['text'] = df['text'].str.decode('ascii')
    
    df['text'] = df['text'].str.replace('[PII]','', regex=True)
    # Replacing characters with whitespace
    df['text'] = df['text'].replace(r'\r+|\n+|\t+|\u2028',' ', regex=True)

    # Replacing punctuations
    df['text'] = df['text'].str.replace('[^\w\s]','', regex=True)

    # Lowercasing reviews
    df['text'] = df['text'].str.lower()
    return df
df = clean_text(df)

# %% [markdown]
# ### Step 3: Identifying key phrases

# %%
def get_insights(sample):
    # Key phrases
    phrases = comprehend.detect_key_phrases(Text=sample, LanguageCode='en')  
    
    return {'phrases':phrases}

# %%
keyphrases_dict = dict()

for answer_i, question_i in zip(df.text.tolist(), list_questions):
    keyphrases_dict[question_i] = get_insights(answer_i)

# %%
keyphrases_dict[df.responce_to_question.tolist()[0]].get('phrases').get('KeyPhrases')[0]
# Out:
# {'Score': 0.9994125962257385,
#  'Text': 'the populist',
#  'BeginOffset': 52,
#  'EndOffset': 64}

# %% [markdown]
# ### Save Results of all KeyPhrases to data frame:

# %%
key_phrases_df = pd.DataFrame()
for q_i in df.responce_to_question.tolist():
    tmp = pd.DataFrame(keyphrases_dict[q_i].get('phrases').get('KeyPhrases'))
    tmp['question'] = q_i
    key_phrases_df = key_phrases_df.append(tmp)

# %%
key_phrases_df.head()
# Out:
#       Score          Text  BeginOffset  EndOffset  \
# 0  0.999413  the populist           52         64
# 1  0.999762  the long run           79         91
# 2  0.986046       benefit          104        111
# 3  0.999053      a decade          121        129
# 4  0.950750   two decades          130        141
#
#                                             question
# 0  As a national savings for the healthcare syste...
# 1  As a national savings for the healthcare syste...
# 2  As a national savings for the healthcare syste...
# 3  As a national savings for the healthcare syste...
# 4  As a national savings for the healthcare syste...

# %% [markdown]
# ####  Consider only TOP key phrases whith confidence score >0.98

# %%
top_key_phrases = key_phrases_df[key_phrases_df.Score>0.98]

# %%
set_of_top_key_phrases = set(top_key_phrases.Text.tolist())

# %%
len(set_of_top_key_phrases)
# Out:
# 461

# %% [markdown]
# ### Detect overall sentiment for answers:

# %%
def get_insights_sentiment(sample):
    # Key phrases
    sentiment = comprehend.detect_sentiment(Text=sample, LanguageCode='en')  
    
    return {'sentiment':sentiment}

# %%
def get_top_500_charackters(input_str, textsize):
    if textsize<5000:
        return input_str
    else:
        return input_str[:500]

# %%
def prepare_input_data(df):
    """Encoding and getting reviews in byte size.
    Review gets encoded to utf-8 format and getting the size of the reviews in bytes. 
    Comprehend requires each review input to be no more than 5000 Bytes
    """
    df['textsize'] = df['text'].apply(lambda x:len(x.encode('utf-8')))
    df['text_for_sentiment'] = ""
    df['text_for_sentiment'] = df[['text','textsize']].apply(lambda x:get_top_500_charackters(x[0],x[1]),axis=1)
    #df = df[(df['textsize'] > 0) & (df['textsize'] < 5000)]
    df = df.drop(columns=['textsize'])
    return df
df = prepare_input_data(df)

# %%
df.head()
# Out:
#                                 responce_to_question  \
# 0  As a national savings for the healthcare syste...
# 1  Fees will be paid to GPS based on the health r...
# 2       From your point of view What is Healthier SG
# 3  If there's one thing that you could you know c...
# 4  Should the typical patient be concerned about ...
#
#                                                 text  \
# 0  if this is running correctly and we get buy in...
# 1  start first what  used to hear a lot of is tha...
# 2   think healthier s g s a whole rethinking of h...
# 3  for me  think information to unify all the inf...
# 4  over time we will see a general increase in co...
#
#                                   text_for_sentiment
# 0  if this is running correctly and we get buy in...
# 1  start first what  used to hear a lot of is tha...
# 2   think healthier s g s a whole rethinking of h...
# 3  for me  think information to unify all the inf...
# 4  over time we will see a general increase in co...

# %%
sentiment_dict = dict()

for answer_i, question_i in zip(df.text_for_sentiment.tolist(), list_questions):
    sentiment_dict[question_i] = get_insights_sentiment(answer_i)

# %%
q_i='As a national savings for the healthcare system will we save money is this is running correctly?'
sentiment_dict[q_i].get('sentiment').get('Sentiment')
# Out:
# 'MIXED'

# %%
sentiment_dict[q_i].get('sentiment')
# Out:
# {'Sentiment': 'MIXED',
#  'SentimentScore': {'Positive': 0.034217070788145065,
#   'Negative': 0.061298761516809464,
#   'Neutral': 0.12324418872594833,
#   'Mixed': 0.781239926815033},
#  'ResponseMetadata': {'RequestId': '52e6fcc5-885d-46d7-8c03-479e159cc46c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '52e6fcc5-885d-46d7-8c03-479e159cc46c',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '160',
#    'date': 'Thu, 09 Mar 2023 03:15:31 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Add a column with overall sentiment to input transcript

# %%
df.head()
# Out:
#                                 responce_to_question  \
# 0  As a national savings for the healthcare syste...
# 1  Fees will be paid to GPS based on the health r...
# 2       From your point of view What is Healthier SG
# 3  If there's one thing that you could you know c...
# 4  Should the typical patient be concerned about ...
#
#                                                 text  \
# 0  if this is running correctly and we get buy in...
# 1  start first what  used to hear a lot of is tha...
# 2   think healthier s g s a whole rethinking of h...
# 3  for me  think information to unify all the inf...
# 4  over time we will see a general increase in co...
#
#                                   text_for_sentiment
# 0  if this is running correctly and we get buy in...
# 1  start first what  used to hear a lot of is tha...
# 2   think healthier s g s a whole rethinking of h...
# 3  for me  think information to unify all the inf...
# 4  over time we will see a general increase in co...

# %%
import numpy as np

# %%
df['overall_sentiment']=""
for q_i in list_questions:
    sentiment_i = sentiment_dict[q_i].get('sentiment').get('Sentiment')
    index_q_i = np.where(df['responce_to_question']==q_i)
    df.at[index_q_i[0][0],'overall_sentiment'] = sentiment_i

# %%
df.head(10)
# Out:
#                                 responce_to_question  \
# 0  As a national savings for the healthcare syste...
# 1  Fees will be paid to GPS based on the health r...
# 2       From your point of view What is Healthier SG
# 3  If there's one thing that you could you know c...
# 4  Should the typical patient be concerned about ...
# 5  The idea of having family doctors is something...
# 6  Will this also add on to increasing burdens fo...
# 7  when you look at our health care system what w...
#
#                                                 text  \
# 0  if this is running correctly and we get buy in...
# 1  start first what  used to hear a lot of is tha...
# 2   think healthier s g s a whole rethinking of h...
# 3  for me  think information to unify all the inf...
# 4  over time we will see a general increase in co...
# 5   dont think were only doing it now  think weve...
# 6  be honest and say that it is going to be certa...
# 7    would actually just extend a little bit from...
#
#                                   text_for_sentiment overall_sentiment
# 0  if this is running correctly and we get buy in...             MIXED
# 1  start first what  used to hear a lot of is tha...           NEUTRAL
# 2   think healthier s g s a whole rethinking of h...           NEUTRAL
# 3  for me  think information to unify all the inf...           NEUTRAL
# 4  over time we will see a general increase in co...             MIXED
# 5   dont think were only doing it now  think weve...          NEGATIVE
# 6  be honest and say that it is going to be certa...           NEUTRAL
# 7    would actually just extend a little bit from...             MIXED

# %%
[ len(val) for val in df.text.tolist()]
# Out:
# [2628, 3768, 2057, 1881, 2049, 4161, 6465, 1824]

# %% [markdown]
# ### Step 4: Extracting context

# %% [markdown]
# ### Analyse sentiment for top key phrases
# We will consider a context +- 10 words around the "key phrase"

# %%
top_key_phrases.columns = ['Score', 'Text', 'BeginOffset', 'EndOffset', 'responce_to_question']

# %%
df_sentiment_top_key_phrases = pd.merge(top_key_phrases,df,on="responce_to_question", how="left")

# %%
df_sentiment_top_key_phrases.head()
# Out:
#       Score          Text  BeginOffset  EndOffset  \
# 0  0.999413  the populist           52         64
# 1  0.999762  the long run           79         91
# 2  0.986046       benefit          104        111
# 3  0.999053      a decade          121        129
# 4  0.999570      the road          147        155
#
#                                 responce_to_question  \
# 0  As a national savings for the healthcare syste...
# 1  As a national savings for the healthcare syste...
# 2  As a national savings for the healthcare syste...
# 3  As a national savings for the healthcare syste...
# 4  As a national savings for the healthcare syste...
#
#                                                 text  \
# 0  if this is running correctly and we get buy in...
# 1  if this is running correctly and we get buy in...
# 2  if this is running correctly and we get buy in...
# 3  if this is running correctly and we get buy in...
# 4  if this is running correctly and we get buy in...
#
#                                   text_for_sentiment overall_sentiment
# 0  if this is running correctly and we get buy in...             MIXED
# 1  if this is running correctly and we get buy in...             MIXED
# 2  if this is running correctly and we get buy in...             MIXED
# 3  if this is running correctly and we get buy in...             MIXED
# 4  if this is running correctly and we get buy in...             MIXED

# %%
def get_top_substring_10_words(BeginOffset,input_str):
    top = input_str[:BeginOffset]
    words = top.split(" ")
    if len(words)>=10:
        # return last 10
        return ' '.join(words[-10:])
    else:
        return ' '.join(words) 
    
def get_last_substring_10_words(EndOffset,input_str):
    top = input_str[EndOffset+1:]
    words = top.split(" ")
    if len(words)>=10:
        # return last 10
        return ' '.join(words[:10])
    else:
        return  ' '.join(words)

# %%
df_sentiment_top_key_phrases["top_10_words"]=""
df_sentiment_top_key_phrases["bottom_10_words"]=""
df_sentiment_top_key_phrases["context"]=""

# %%
df_sentiment_top_key_phrases["top_10_words"]=df_sentiment_top_key_phrases[["BeginOffset","text"]].apply(
lambda x: get_top_substring_10_words(x[0],x[1]),axis=1)
df_sentiment_top_key_phrases["bottom_10_words"]=df_sentiment_top_key_phrases[["EndOffset","text"]].apply(
lambda x: get_last_substring_10_words(x[0],x[1]),axis=1)

# %%
def concat_str(top_5_words,Text,bottom_5_words):
    return str(top_5_words)+" "+str(Text)+" "+str(bottom_5_words)

# %%
df_sentiment_top_key_phrases["context"]=df_sentiment_top_key_phrases[["top_10_words",
                                                                      "Text",
                                                                     "bottom_10_words"
                                                                     ]].apply(lambda x:concat_str(x[0],x[1],x[0]),axis=1)

# %%
df_sentiment_top_key_phrases.head()
# Out:
#       Score          Text  BeginOffset  EndOffset  \
# 0  0.999413  the populist           52         64
# 1  0.999762  the long run           79         91
# 2  0.986046       benefit          104        111
# 3  0.999053      a decade          121        129
# 4  0.999570      the road          147        155
#
#                                 responce_to_question  \
# 0  As a national savings for the healthcare syste...
# 1  As a national savings for the healthcare syste...
# 2  As a national savings for the healthcare syste...
# 3  As a national savings for the healthcare syste...
# 4  As a national savings for the healthcare syste...
#
#                                                 text  \
# 0  if this is running correctly and we get buy in...
# 1  if this is running correctly and we get buy in...
# 2  if this is running correctly and we get buy in...
# 3  if this is running correctly and we get buy in...
# 4  if this is running correctly and we get buy in...
#
#                                   text_for_sentiment overall_sentiment  \
# 0  if this is running correctly and we get buy in...             MIXED
# 1  if this is running correctly and we get buy in...             MIXED
# 2  if this is running correctly and we get buy in...             MIXED
# 3  if this is running correctly and we get buy in...             MIXED
# 4  if this is running correctly and we get buy in...             MIXED
#
#                                       top_10_words  \
# 0     is running correctly and we get buy in from
# 1          buy in from the populist  would say in
# 2           would say in the long run we will see
# 3       the long run we will see benefit you know
# 4  see benefit you know a decade two decades down
#
#                                      bottom_10_words  \
# 0              would say in the long run we will see
# 1  we will see benefit you know a decade two decades
# 2    you know a decade two decades down the road for
# 3    two decades down the road for sure feel that it
# 4  for sure feel that it takes a generation thats...
#
#                                              context
# 0  is running correctly and we get buy in from  t...
# 1  buy in from the populist  would say in  the lo...
# 2  would say in the long run we will see  benefit...
# 3  the long run we will see benefit you know  a d...
# 4  see benefit you know a decade two decades down...

# %%
df_sentiment_top_key_phrases.shape
# Out:
# (559, 11)

# %% [markdown]
# ### Step 5: Detecting sentiment for key phrases:

# %%
context = df_sentiment_top_key_phrases.context.tolist()

# %%
sentiment_dict = dict()
key_phrases_list = df_sentiment_top_key_phrases.Text.tolist()
ind = 0
for phrase_i, context_i in zip(key_phrases_list, context):
    sentiment_dict[ind] = get_insights_sentiment(context_i)
    ind = ind+1

# %%
df_sentiment_top_key_phrases =df_sentiment_top_key_phrases[['Score', 'Text', 'BeginOffset', 'EndOffset', 'responce_to_question',
       'text', 'overall_sentiment','context']]

# %%
for i, phrase in enumerate(key_phrases_list):
    sentiment_i = sentiment_dict[i].get('sentiment').get('Sentiment')
    df_sentiment_top_key_phrases.at[i,'key_phrase_sentiment'] = sentiment_i

# %%
df_sentiment_top_key_phrases[df_sentiment_top_key_phrases.key_phrase_sentiment == "NEGATIVE"].head(30)
# Out:
#         Score                                               Text  BeginOffset  \
# 26   0.999519                                             rescue         1224
# 31   0.999938                                 the very long term         1534
# 38   0.999848                                           the fact         1855
# 40   0.988433                                       greater risk         1908
# 47   0.984725  this particular family doctor family doctor group         2179
# 59   0.999603                                the individual case           53
# 73   0.999572                                              a bit          757
# 76   0.997937                                        the patient          793
# 77   0.999288                                   our best efforts          848
# 78   0.995523                              very large scale kind          905
# 88   0.998823                                             a pool         1206
# 100  0.999727                                             a bias         1697
# 101  0.998452                             the healthier patients         1720
# 104  0.999018                                  the whole purpose         1834
# 112  0.999872                                   certain segments         2225
# 113  0.999779                                         population         2245
# 173  0.999706                                          the issue         1017
# 181  0.997218                                             school         1380
# 183  0.998566                                          my family         1568
# 194  0.998161                                all the information           35
# 220  0.999921                                     the population          876
# 229  0.999239                                       other things         1563
# 230  0.998611                                      the ecosystem         1598
# 238  0.999746                                               time            5
# 243  0.999259                                             a heck          140
# 244  0.999819                                              a lot          150
# 245  0.999813                                      an individual          165
# 248  0.999160                                           a doctor          272
# 252  0.999967                                      the same drug          348
# 253  0.999396                                 the same decisions          366
#
#      EndOffset                               responce_to_question  \
# 26        1230  As a national savings for the healthcare syste...
# 31        1552  As a national savings for the healthcare syste...
# 38        1863  As a national savings for the healthcare syste...
# 40        1920  As a national savings for the healthcare syste...
# 47        2228  As a national savings for the healthcare syste...
# 59          72  Fees will be paid to GPS based on the health r...
# 73         762  Fees will be paid to GPS based on the health r...
# 76         804  Fees will be paid to GPS based on the health r...
# 77         864  Fees will be paid to GPS based on the health r...
# 78         926  Fees will be paid to GPS based on the health r...
# 88        1212  Fees will be paid to GPS based on the health r...
# 100       1703  Fees will be paid to GPS based on the health r...
# 101       1742  Fees will be paid to GPS based on the health r...
# 104       1851  Fees will be paid to GPS based on the health r...
# 112       2241  Fees will be paid to GPS based on the health r...
# 113       2255  Fees will be paid to GPS based on the health r...
# 173       1026       From your point of view What is Healthier SG
# 181       1386       From your point of view What is Healthier SG
# 183       1577       From your point of view What is Healthier SG
# 194         54  If there's one thing that you could you know c...
# 220        890  If there's one thing that you could you know c...
# 229       1575  If there's one thing that you could you know c...
# 230       1611  If there's one thing that you could you know c...
# 238          9  Should the typical patient be concerned about ...
# 243        146  Should the typical patient be concerned about ...
# 244        155  Should the typical patient be concerned about ...
# 245        178  Should the typical patient be concerned about ...
# 248        280  Should the typical patient be concerned about ...
# 252        361  Should the typical patient be concerned about ...
# 253        384  Should the typical patient be concerned about ...
#
#                                                   text overall_sentiment  \
# 26   if this is running correctly and we get buy in...             MIXED
# 31   if this is running correctly and we get buy in...             MIXED
# 38   if this is running correctly and we get buy in...             MIXED
# 40   if this is running correctly and we get buy in...             MIXED
# 47   if this is running correctly and we get buy in...             MIXED
# 59   start first what  used to hear a lot of is tha...           NEUTRAL
# 73   start first what  used to hear a lot of is tha...           NEUTRAL
# 76   start first what  used to hear a lot of is tha...           NEUTRAL
# 77   start first what  used to hear a lot of is tha...           NEUTRAL
# 78   start first what  used to hear a lot of is tha...           NEUTRAL
# 88   start first what  used to hear a lot of is tha...           NEUTRAL
# 100  start first what  used to hear a lot of is tha...           NEUTRAL
# 101  start first what  used to hear a lot of is tha...           NEUTRAL
# 104  start first what  used to hear a lot of is tha...           NEUTRAL
# 112  start first what  used to hear a lot of is tha...           NEUTRAL
# 113  start first what  used to hear a lot of is tha...           NEUTRAL
# 173   think healthier s g s a whole rethinking of h...           NEUTRAL
# 181   think healthier s g s a whole rethinking of h...           NEUTRAL
# 183   think healthier s g s a whole rethinking of h...           NEUTRAL
# 194  for me  think information to unify all the inf...           NEUTRAL
# 220  for me  think information to unify all the inf...           NEUTRAL
# 229  for me  think information to unify all the inf...           NEUTRAL
# 230  for me  think information to unify all the inf...           NEUTRAL
# 238  over time we will see a general increase in co...             MIXED
# 243  over time we will see a general increase in co...             MIXED
# 244  over time we will see a general increase in co...             MIXED
# 245  over time we will see a general increase in co...             MIXED
# 248  over time we will see a general increase in co...             MIXED
# 252  over time we will see a general increase in co...             MIXED
# 253  over time we will see a general increase in co...             MIXED
#
#                                                context key_phrase_sentiment
# 26   with the condition fairly late where the cost ...             NEGATIVE
# 31   of which we cant afford as a nation in  the ve...             NEGATIVE
# 38   the beginning of life and  didnt allude to  th...             NEGATIVE
# 40   we had to start with the ones that are  greate...             NEGATIVE
# 47   over time even the kids will end up seeing  th...             NEGATIVE
# 59   used to hear a lot of is that when  the indivi...             NEGATIVE
# 73   get amply compensated in that sense so that re...             NEGATIVE
# 76   a bit of the burden and the risk of  the patie...             NEGATIVE
# 77   risk of the patient just being completely nonc...             NEGATIVE
# 78   then the other part about it is that on  very ...             NEGATIVE
# 88   be better from that basis right f  manage  a p...             NEGATIVE
# 100  you ask me is that they may potentially be  a ...             NEGATIVE
# 101  that they may potentially be a bias towards ke...             NEGATIVE
# 104  cases which then creates a negative cycle and ...             NEGATIVE
# 112  information knowledge which may make it more d...             NEGATIVE
# 113  may make it more difficult for certain segment...             NEGATIVE
# 173  from the populist and thats really the crux of...             NEGATIVE
# 181  page and its sort of like going back to  schoo...             NEGATIVE
# 183  after myself you know ve got to look after  my...             NEGATIVE
# 194  for me  think information to unify  all the in...             NEGATIVE
# 220  vaccines out there and unfortunately a huge pr...             NEGATIVE
# 229  deal with covid and everything else and weve h...             NEGATIVE
# 230  had other things to do to try to build  the ec...             NEGATIVE
# 238                                   over  time over              NEGATIVE
# 243  ve actually looked at the system costs it cost...             NEGATIVE
# 244  at the system costs it costs a heck of  a lot ...             NEGATIVE
# 245  it costs a heck of a lot more for  an individu...             NEGATIVE
# 248  then it cost for them to go and see  a doctor ...             NEGATIVE
# 252  things being equal if they could get access to...             NEGATIVE
# 253  they could get access to the same drug and  th...             NEGATIVE

# %% [markdown]
# ### Saving Results:

# %%
df_sentiment_top_key_phrases.to_csv("data/key_phrases_sentiment.csv", index=False)

# %%
df.to_csv("data/overall_sentiment_for_question_replies.csv", index=False)

# %%
key_phrases_df.to_csv("data/all_key_phrases.csv",index=False)
